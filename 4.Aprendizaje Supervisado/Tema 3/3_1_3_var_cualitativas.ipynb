# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Grado' 'Master' 'Master' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Master' 'Secundaria' 'Grado'
#  'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Master'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Secundaria' 'Grado'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria' 'Master' 'Grado'
#  'Master' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Secundaria'
#  'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Master' 'Grado' 'Grado' 'Secundaria'
#  'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Master' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria' 'Master' 'Grado'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Doctorado' 'Secundaria' 'Grado' 'Master' 'Secundaria' 'Master'
#  'Doctorado' 'Secundaria' 'Grado' 'Doctorado' 'Secundaria' 'Doctorado'
#  'Master' 'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado'
#  'Grado' 'Bachillerato' 'Doctorado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Master'
#  'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Doctorado' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Master'
#  'Grado' 'Grado' 'Secundaria' 'Doctorado' 'Grado' 'Master' 'Bachillerato'
#  'Doctorado' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Grado' 'Master' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Master' 'Bachillerato' 'Secundaria' 'Grado' 'Master'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Grado' 'Secundaria' 'Grado' 'Master' 'Master' 'Grado' 'Grado' 'Grado'
#  'Master' 'Secundaria' 'Master' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Master'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Master' 'Master' 'Secundaria'
#  'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Master' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Grado' 'Grado' 'Doctorado' 'Master' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Grado'
#  'Master' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Master' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master'
#  'Grado' 'Bachillerato' 'Master' 'Bachillerato' 'Master' 'Master'
#  'Doctorado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Doctorado' 'Master' 'Grado' 'Grado' 'Grado' 'Master' 'Grado'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Master' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Master' 'Bachillerato' 'Bachillerato' 'Master'
#  'Bachillerato' 'Master' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Doctorado' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Master' 'Bachillerato' 'Master' 'Bachillerato' 'Secundaria' 'Grado'
#  'Master' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Doctorado' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria' 'Master'
#  'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Doctorado' 'Grado' 'Master' 'Grado' 'Doctorado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Doctorado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Grado'
#  'Bachillerato' 'Doctorado' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Doctorado']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()
